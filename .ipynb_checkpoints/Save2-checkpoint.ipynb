# %%
import pandas as pd

# %%
df_pitch_subs = pd.read_csv('pitching_subs.csv')

# %%
df_pitch_subs['made_save'] = None
df_pitch_subs['IP'] = 0
df_next_pitcher = df_pitch_subs.shift(-1).reset_index()

# our csv already tells us which pitcher gets the save, so we will leave that calculation to the scorer
# need to check if any relief pitchers either blow,or neither get a S/BS
# for now, let's just see if they blow it based on the state of the game when they come in, and get pulled/end of game
# we know that if they come in with a lead, and leave with the game tied/losing, they blew it
for (cur_index, cur_row), (_, next_row) in zip(df_pitch_subs.iterrows(), df_next_pitcher.iterrows()):
    # made_save will be True(completed save), False(blew save), or None(neither completed or blew)\
    made_save = None
    
    # We will check the state of the game when the pitcher came in (cur_row)
    # as well as the state of the game with the pitcher stopped pitching (next_row)
    
    # make sure next event is the same game, and the same team
    if cur_row['GAME_ID'] == next_row['GAME_ID'] and cur_row['HOME_TEAM'] == next_row['HOME_TEAM']:
        
        # IP will be number if innings pitched
        IP = float(next_row['INN_CT'] - cur_row['INN_CT']) + float((1.0/3.0)*next_row['OUTS_CT']) - float((1.0/3.0)*cur_row['OUTS_CT'])
        
        # home
        if cur_row['HOME_TEAM'] == 1:
            # blew lead if winning in initial state, and losing in their last state
            blew_lead = next_row['HOME_SCORE_CT'] <= next_row['AWAY_SCORE_CT']
            if blew_lead:
                # Definition of Save Opportunity
                # He is credited with at least ⅓ of an inning pitched; and
                #He satisfies one of the following conditions:
                    #1 He enters the game with a lead of no more than three runs and pitches for at least one inning
                    #2 He enters the game, regardless of the count, with the potential tying run either on base, at bat or on deck
                    #3 He pitches for at least three innings.
                    
                if IP > 0:
                    init_score_diff = cur_row['HOME_SCORE_CT'] - cur_row['AWAY_SCORE_CT']
                
                    # save #1 or #2 or #3
                    if (init_score_diff <= 3 and inn_diff >= 1) or (IP >= 3) or (cur_row['HOME_SCORE_CT'] <= cur_row['AWAY_SCORE_CT'] + 2 + sum([cur_row['RUNNER_FIRST'], cur_row['RUNNER_SECOND'], cur_row['RUNNER_THIRD']])):
                        made_save = False    
        #away
        elif cur_row['HOME_TEAM'] == 0:
            # blew lead if winning in initial state, and losing in their last state
            blew_lead = next_row['HOME_SCORE_CT'] >= next_row['AWAY_SCORE_CT']
            if blew_lead:
                inn_diff = next_row['INN_CT'] - cur_row['INN_CT']
                init_score_diff = cur_row['AWAY_SCORE_CT'] - cur_row['HOME_SCORE_CT']
                
                # Save #1 or #2 or #3
                if (init_score_diff <= 3 and IP >= 1) or (IP >= 3) or (cur_row['AWAY_SCORE_CT'] <= cur_row['HOME_SCORE_CT'] + 2 + sum([cur_row['RUNNER_FIRST'], cur_row['RUNNER_SECOND'], cur_row['RUNNER_THIRD']])):
                    made_save = False
    else:
        # calculate IP if last pitcher of game
        IP = cur_row['TOTAL_INN'] - cur_row['INN_CT'] + 1 - float((1.0/3.0)*cur_row['OUTS_CT'])
    # Use Retrosheet to determine if this pitcher was the one who got a save
    if cur_row['PIT_ID'] == cur_row['SAVE_PIT_ID']:
        made_save = True
    
    
    
    # place made_save, IP into the dataframe at the correct index
    df_pitch_subs.iloc[cur_index, df_pitch_subs.columns.get_loc('made_save')] = made_save
    df_pitch_subs.iloc[cur_index, df_pitch_subs.columns.get_loc('IP')] = float(round(IP, 2))

df_pitch_subs.head()
# Out:
#         GAME_ID  EVENT_ID  INN_CT  TOTAL_INN  HOME_TEAM  OUTS_CT  \
# 0  ANA201004050        54       7          9          1        0
# 1  ANA201004050        64       8          9          1        0
# 2  ANA201004050        74       9          9          1        0
# 3  ANA201004050        44       5          9          0        2
# 4  ANA201004050        61       7          9          0        1
#
#    HOME_SCORE_CT  AWAY_SCORE_CT  RUNNER_FIRST  RUNNER_SECOND  RUNNER_THIRD  \
# 0              4              3             0              0             0
# 1              4              3             0              0             0
# 2              6              3             0              0             0
# 3              4              3             1              0             1
# 4              4              3             0              0             0
#
#      PIT_ID SAVE_PIT_ID        FULL_NAME made_save    IP
# 0  jepsk001    fuenb001     Kevin Jepsen      None  1.00
# 1  rodnf001    fuenb001  Fernando Rodney      None  1.00
# 2  fuenb001    fuenb001    Brian Fuentes      True  1.00
# 3  craij001    fuenb001      Jesse Crain     False  1.67
# 4  mijaj001    fuenb001     Jose Mijares     False  0.67

# %%
# We already know if a pitcher lost a lead when, but we dont know if they were even entering into a save opportunity
# A Save Opportunity (SvO) happens when a relief pitcher enters the game with a lead
# Above, we didnt check to make sure they were in the lead when they entered the game
def save_sit(row):
    if row['HOME_TEAM'] == 1 and row['HOME_SCORE_CT'] > row['AWAY_SCORE_CT']:
        if row['IP'] > 0:
            init_score_diff = cur_row['HOME_SCORE_CT'] - cur_row['AWAY_SCORE_CT']
            # save #1 or #2 or #3
            if (init_score_diff <= 3 and row['IP'] >= 1) or (row['IP'] >= 3) or (cur_row['HOME_SCORE_CT'] >= cur_row['AWAY_SCORE_CT'] + 2 + sum([cur_row['RUNNER_FIRST'], cur_row['RUNNER_SECOND'], cur_row['RUNNER_THIRD']])):
                return True 
        
    elif row['HOME_TEAM'] == 0 and row['HOME_SCORE_CT'] < row['AWAY_SCORE_CT']:
        if row['IP'] > 0:
            init_score_diff = cur_row['HOME_SCORE_CT'] - cur_row['AWAY_SCORE_CT']
            # save #1 or #2 or #3
            if (init_score_diff <= 3 and row['IP'] >= 1) or (row['IP'] >= 3) or (cur_row['AWAY_SCORE_CT'] >= cur_row['HOME_SCORE_CT'] + 2 + sum([cur_row['RUNNER_FIRST'], cur_row['RUNNER_SECOND'], cur_row['RUNNER_THIRD']])):
                return True 
    return False
df_pitch_subs['SAVE_SIT'] = df_pitch_subs.apply(save_sit, axis=1)

# we know if a pitcher entered into a SvO, so let's disregard all the pitchers who didn't
# we know that all these pitchers are in SvOs and who got the save, we can drop some data that we don't need
df_pitch_subs = df_pitch_subs[df_pitch_subs['SAVE_SIT'] == True].drop(['SAVE_PIT_ID', 'SAVE_SIT'], axis=1).reset_index(drop=True)

df_pitch_subs.head()
# Out:
#         GAME_ID  EVENT_ID  INN_CT  TOTAL_INN  HOME_TEAM  OUTS_CT  \
# 0  ANA201004050        54       7          9          1        0
# 1  ANA201004050        64       8          9          1        0
# 2  ANA201004050        74       9          9          1        0
# 3  ANA201004060        68       8          9          0        0
# 4  ANA201004060        74       9          9          0        0
#
#    HOME_SCORE_CT  AWAY_SCORE_CT  RUNNER_FIRST  RUNNER_SECOND  RUNNER_THIRD  \
# 0              4              3             0              0             0
# 1              4              3             0              0             0
# 2              6              3             0              0             0
# 3              3              5             0              0             0
# 4              3              5             0              0             0
#
#      PIT_ID        FULL_NAME made_save   IP
# 0  jepsk001     Kevin Jepsen      None  1.0
# 1  rodnf001  Fernando Rodney      None  1.0
# 2  fuenb001    Brian Fuentes      True  1.0
# 3  guerm001    Matt Guerrier      None  1.0
# 4  raucj001        Jon Rauch      True  1.0

# %%
def sit_id(row):
    # '<start_inn(2)><start_out><score_diff><runners_on><IP>'
    score_diff = row['HOME_SCORE_CT'] - row['AWAY_SCORE_CT'] if row['HOME_TEAM'] else row['AWAY_SCORE_CT'] - row['HOME_SCORE_CT']
    runners_on = sum([row['RUNNER_FIRST'], row['RUNNER_SECOND'], row['RUNNER_THIRD']])
    inn = '0' + str(row['INN_CT']) if len(str(row['INN_CT'])) == 1 else str(row['INN_CT'])
    return str(inn) + str(row['OUTS_CT']) + str(score_diff) + str(runners_on) + str(row['IP'])

df_pitch_subs['sit_id'] = df_pitch_subs.apply(sit_id, axis=1)
df_pitch_subs.head()
# Out:
#         GAME_ID  EVENT_ID  INN_CT  TOTAL_INN  HOME_TEAM  OUTS_CT  \
# 0  ANA201004050        54       7          9          1        0
# 1  ANA201004050        64       8          9          1        0
# 2  ANA201004050        74       9          9          1        0
# 3  ANA201004060        68       8          9          0        0
# 4  ANA201004060        74       9          9          0        0
#
#    HOME_SCORE_CT  AWAY_SCORE_CT  RUNNER_FIRST  RUNNER_SECOND  RUNNER_THIRD  \
# 0              4              3             0              0             0
# 1              4              3             0              0             0
# 2              6              3             0              0             0
# 3              3              5             0              0             0
# 4              3              5             0              0             0
#
#      PIT_ID        FULL_NAME made_save   IP    sit_id
# 0  jepsk001     Kevin Jepsen      None  1.0  070101.0
# 1  rodnf001  Fernando Rodney      None  1.0  080101.0
# 2  fuenb001    Brian Fuentes      True  1.0  090301.0
# 3  guerm001    Matt Guerrier      None  1.0  080201.0
# 4  raucj001        Jon Rauch      True  1.0  090201.0

# %%
df_pitch_subs = df_pitch_subs.drop(df_pitch_subs[(df_pitch_subs.made_save != True) & (df_pitch_subs.made_save != False)].index)
df_pitch_subs
# Out:
#             GAME_ID  EVENT_ID  INN_CT  TOTAL_INN  HOME_TEAM  OUTS_CT  \
# 2      ANA201004050        74       9          9          1        0
# 4      ANA201004060        74       9          9          0        0
# 6      ANA201004070        70       9          9          0        0
# 12     ANA201004100        62       8          9          1        0
# 13     ANA201004110        49       7          9          1        0
# 14     ANA201004110        53       7          9          0        0
# 15     ANA201004190        63       9          9          1        0
# 17     ANA201004200        79       9          9          1        0
# 19     ANA201004210        73       9          9          0        0
# 22     ANA201004220        84       9          9          0        0
# 23     ANA201004230        78       9          9          1        0
# 28     ANA201004260        81       9          9          1        0
# 33     ANA201005120        79       9          9          0        0
# 49     ANA201006220        72       9          9          1        0
# 50     ANA201006230        63       9          9          1        0
# 54     ANA201006250        57       8         11          1        0
# 55     ANA201006250        90      11         11          0        0
# 57     ANA201006260        61       9          9          1        0
# 62     ANA201006290        84       9          9          1        0
# 65     ANA201006300        79       9          9          0        0
# 67     ANA201007010        68       9          9          1        0
# 68     ANA201007020        66       9         10          1        0
# 69     ANA201007020        83      10         10          0        0
# 70     ANA201007030        69       9          9          0        0
# 76     ANA201007160        67       9          9          1        0
# 79     ANA201007170        74       9          9          1        0
# 80     ANA201007180        81      10         10          0        0
# 81     ANA201007260        69       8          9          0        2
# 82     ANA201007270        77       9          9          0        0
# 87     ANA201007300        82       9          9          1        0
# ...             ...       ...     ...        ...        ...      ...
# 12810  WAS201209080        80       9         10          0        0
# 12812  WAS201209192        81       9          9          0        0
# 12814  WAS201209210        67       9          9          0        0
# 12818  WAS201210010        66       9          9          0        0
# 12826  WAS201304030        66       9          9          1        0
# 12831  WAS201304110        83       9          9          1        0
# 12833  WAS201304130        70       9          9          0        0
# 12837  WAS201304240        71       9          9          0        0
# 12840  WAS201304280        76       9          9          0        0
# 12841  WAS201305080        67       9          9          1        0
# 12852  WAS201306210        66       9          9          1        0
# 12855  WAS201306230        78       8          9          0        2
# 12857  WAS201306250        77       9          9          1        0
# 12858  WAS201306260        64       9          9          1        0
# 12862  WAS201307040        81       9          9          1        0
# 12864  WAS201307050        75       9          9          1        0
# 12866  WAS201307060        72       9          9          1        0
# 12868  WAS201307190        70       9          9          0        0
# 12869  WAS201307200        89      10         10          0        0
# 12873  WAS201307240        67       9          9          0        0
# 12874  WAS201307270        60       9          9          1        0
# 12879  WAS201308060        72       9          9          0        0
# 12880  WAS201308070        75       9          9          0        0
# 12882  WAS201308100        76       9          9          1        0
# 12885  WAS201308140        71       9          9          1        0
# 12890  WAS201308270        67       9          9          1        0
# 12892  WAS201308300        67       9          9          0        0
# 12897  WAS201309140        84       9          9          0        0
# 12899  WAS201309171        50       7          9          1        0
# 12904  WAS201309190        70       9          9          1        0
#
#        HOME_SCORE_CT  AWAY_SCORE_CT  RUNNER_FIRST  RUNNER_SECOND  \
# 2                  6              3             0              0
# 4                  3              5             0              0
# 6                  1              4             0              0
# 12                 3              2             0              0
# 13                 3              2             0              1
# 14                 3              4             0              0
# 15                 2              0             0              0
# 17                 6              5             0              0
# 19                 3              4             0              0
# 22                 4              5             0              0
# 23                 6              4             0              0
# 28                 5              2             0              0
# 33                 3              4             0              0
# 49                 6              3             0              0
# 50                 2              1             0              0
# 54                 3              2             0              0
# 55                 3              4             1              0
# 57                 4              2             0              0
# 62                 6              5             0              0
# 65                 4              6             0              0
# 67                 2              1             0              0
# 68                 1              0             1              0
# 69                 1              2             0              0
# 70                 1              4             0              0
# 76                 3              2             0              0
# 79                 7              6             0              0
# 80                 1              2             0              0
# 81                 3              4             0              0
# 82                 2              4             0              0
# 87                 9              7             0              0
# ...              ...            ...           ...            ...
# 12810              5              6             0              0
# 12812              6              7             0              0
# 12814              2              4             0              0
# 12818              0              2             0              0
# 12826              3              0             0              0
# 12831              7              4             0              0
# 12833              1              3             0              0
# 12837              2              4             0              0
# 12840              2              5             0              0
# 12841              3              1             0              0
# 12852              2              1             0              0
# 12855              4              7             1              0
# 12857              7              4             0              0
# 12858              3              2             0              0
# 12862              8              5             0              0
# 12864              8              5             0              0
# 12866              5              4             0              0
# 12868              2              3             0              0
# 12869              1              3             0              0
# 12873              2              4             0              0
# 12874              4              1             0              0
# 12879              1              2             0              0
# 12880              3              6             0              0
# 12882              8              5             0              0
# 12885              6              4             0              0
# 12890              2              1             0              0
# 12892              2              3             0              0
# 12897              4              5             0              0
# 12899              3              1             0              0
# 12904              3              2             0              0
#
#        RUNNER_THIRD    PIT_ID          FULL_NAME made_save    IP     sit_id
# 2                 0  fuenb001      Brian Fuentes      True  1.00   090301.0
# 4                 0  raucj001          Jon Rauch      True  1.00   090201.0
# 6                 0  raucj001          Jon Rauch      True  1.00   090301.0
# 12                0  shies002       Scot Shields     False  1.00   080101.0
# 13                1  jepsk001       Kevin Jepsen     False  1.00   070121.0
# 14                0  rosst001         Tyson Ross      True  3.00   070103.0
# 15                0  rodnf001    Fernando Rodney      True  1.00   090201.0
# 17                0  rodnf001    Fernando Rodney      True  1.00   090101.0
# 19                0  valvj001      Jose Valverde      True  1.00   090101.0
# 22                0  valvj001      Jose Valverde      True  1.00   090101.0
# 23                0  fuenb001      Brian Fuentes      True  1.00   090201.0
# 28                0  fuenb001      Brian Fuentes      True  1.00   090301.0
# 33                0  sorir001     Rafael Soriano      True  1.00   090101.0
# 49                0  fuenb001      Brian Fuentes      True  1.00   090301.0
# 50                0  fuenb001      Brian Fuentes      True  1.00   090101.0
# 54                0  rodnf001    Fernando Rodney     False  1.00   080101.0
# 55                0  corpm001      Manuel Corpas      True  1.00   110111.0
# 57                0  fuenb001      Brian Fuentes      True  1.00   090201.0
# 62                0  fuenb001      Brian Fuentes      True  1.00   090101.0
# 65                0  felin001      Neftali Feliz      True  1.00   090201.0
# 67                0  fuenb001      Brian Fuentes      True  1.00   090101.0
# 68                0  fuenb001      Brian Fuentes     False  1.00   090111.0
# 69                0  sorij001       Joakim Soria      True  1.00   100101.0
# 70                0  sorij001       Joakim Soria      True  1.00   090301.0
# 76                0  fuenb001      Brian Fuentes      True  1.00   090101.0
# 79                0  fuenb001      Brian Fuentes      True  1.00   090101.0
# 80                0  aardd001      David Aardsma      True  1.00   100101.0
# 81                0  papej001  Jonathan Papelbon      True  1.33  082101.33
# 82                0  papej001  Jonathan Papelbon      True  1.00   090201.0
# 87                0  fuenb001      Brian Fuentes      True  1.00   090201.0
# ...             ...       ...                ...       ...   ...        ...
# 12810             0  bellh001         Heath Bell     False  1.00   090101.0
# 12812             0  leagb001     Brandon League      True  1.00   090101.0
# 12814             0  axfoj001        John Axford      True  1.00   090201.0
# 12818             0  aumop001   Phillippe Aumont      True  1.00   090201.0
# 12826             0  sorir001     Rafael Soriano      True  1.00   090301.0
# 12831             0  sorir001     Rafael Soriano      True  1.00   090301.0
# 12833             0  kimbc001      Craig Kimbrel      True  1.00   090201.0
# 12837             0  mujie001      Edward Mujica      True  1.00   090201.0
# 12840             0  chapa001    Aroldis Chapman      True  1.00   090301.0
# 12841             0  sorir001     Rafael Soriano      True  1.00   090201.0
# 12852             0  sorir001     Rafael Soriano      True  1.00   090101.0
# 12855             1  brotr001       Rex Brothers      True  1.33  082321.33
# 12857             0  sorir001     Rafael Soriano      True  1.00   090301.0
# 12858             0  sorir001     Rafael Soriano      True  1.00   090101.0
# 12862             0  sorir001     Rafael Soriano      True  1.00   090301.0
# 12864             0  sorir001     Rafael Soriano      True  1.00   090301.0
# 12866             0  sorir001     Rafael Soriano      True  1.00   090101.0
# 12868             0  jansk001      Kenley Jansen      True  1.00   090101.0
# 12869             0  jansk001      Kenley Jansen      True  1.00   100201.0
# 12873             0  melam001      Mark Melancon      True  1.00   090201.0
# 12874             0  sorir001     Rafael Soriano      True  1.00   090301.0
# 12879             0  kimbc001      Craig Kimbrel      True  1.00   090101.0
# 12880             0  kimbc001      Craig Kimbrel      True  1.00   090301.0
# 12882             0  sorir001     Rafael Soriano      True  1.00   090301.0
# 12885             0  sorir001     Rafael Soriano      True  1.00   090201.0
# 12890             0  sorir001     Rafael Soriano      True  1.00   090101.0
# 12892             0  hawkl001     LaTroy Hawkins      True  1.00   090101.0
# 12897             0  papej001  Jonathan Papelbon      True  1.00   090101.0
# 12899             0  stord001        Drew Storen     False  2.00   070202.0
# 12904             0  sorir001     Rafael Soriano      True  1.00   090101.0
#
# [3808 rows x 16 columns]

# %%
df_pitch_subs[df_pitch_subs['made_save'] == True].groupby('sit_id').size().to_csv('made.csv')
df_pitch_subs[df_pitch_subs['made_save'] == False].groupby('sit_id').size().to_csv('blown.csv')

# %%
df_pitch_subs.groupby('PIT_ID').size()
# Out:
# PIT_ID
# aardd001     30
# abadf001      2
# accaj001      2
# aceva001     29
# acosm001      4
# adamm001      4
# adcon001      1
# affej001      2
# albem001      1
# albua001      2
# allec002      2
# ambrh001      3
# andeb004      3
# arrej001      1
# atchs001      1
# aumop001      2
# avill001      1
# axfoj001     56
# ayall001      7
# badeb001      1
# baila001     63
# balfg001     65
# bardd001     10
# barns002      1
# basta001      9
# batim001      2
# beatp001      1
# beavb001      1
# bedae001      2
# belim001      9
#            ...
# tuckr001      1
# uehak001     38
# valdr002      1
# valvj001    121
# varva001      1
# vasqe001      1
# ventj001      2
# veraj001     19
# villc001      3
# vizca001      1
# wadec001      1
# wagnb001     19
# waldj001     36
# warra001      1
# webbr001      5
# weinr001      1
# wheed001      3
# wilht001     52
# willj003      1
# wilsb001     38
# wilsj004      2
# woodb004      3
# woodk002     10
# workb001      1
# wrigj001      4
# wrigw001      4
# wuerm001      6
# zeidj001      1
# ziegb001      5
# zumaj001      3
# Length: 365, dtype: int64
